# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
barragem = pd.read_csv('fiscalizacao-seguranca-barragem.csv',encoding='latin1',
                       sep=';')
barragem.head()
# Out:
#   DatGeracaoConjuntoDados  IdeNucleoCEG       NomUsina  \
# 0              2024-05-01          66.0  Alto Araguaia
# 1              2024-05-01          76.0    Alto Jatapu
# 2              2024-05-01          76.0    Alto Jatapu
# 3              2024-05-01          76.0    Alto Jatapu
# 4              2024-05-01          76.0    Alto Jatapu
#
#                NomEmpresa       NomBarramento   DscTipo  \
# 0  PRIMAVERA ENERGIA S.A.       Alto Araguaia  Barragem
# 1    Roraima Energia S.A.  BARRAGEM PRINCIPAL  Barragem
# 2    Roraima Energia S.A.          VERTEDOURO  Barragem
# 3    Roraima Energia S.A.               USINA  Barragem
# 4    Roraima Energia S.A.           DIQUE N°1     Dique
#
#   DscNivelSegurancaBarragem IdcClassificacaoBarragens DscCategoriaRiscoGeral  \
# 0                    Normal                         C                  BAIXO
# 1                    Normal                         C                  BAIXO
# ...

# %%
barragem.shape
# Out:
# (11596, 86)

# %%
barragem.isna().sum()[0:31]
# Out:
# DatGeracaoConjuntoDados            0
# IdeNucleoCEG                     119
# NomUsina                         119
# NomEmpresa                       119
# NomBarramento                      5
# DscTipo                            0
# DscNivelSegurancaBarragem          0
# IdcClassificacaoBarragens       1110
# DscCategoriaRiscoGeral          1110
# DscDanoPotencialGeral              0
# DscVersao                          0
# NomCampanha                        0
# DatInicioCampanha                  0
# DatFimCampanha                     0
# DatInicioPrazoLegalCampanha        0
# DatFimPrazoLegalCampanha           0
# NomSecundario                   2912
# DatInicioConstrucao             8657
# DatConclusaoConstrucao             0
# MdaAlturaMacicoTerreno          3001
# MdaAlturaMacicoFundacao            3
# MdaComprimento                     0
# NumBarramento                      0
# DscExisteAcidenteIncidente         0
# QtdAcidenteIncidente               0
# ...

# %%
barragem.isna().sum()[61:87]
# Out:
# DscEmiteRelatorio                1110
# DscTamanhoVolumeReservatorio        0
# DscProbabilidadeMorte               0
# DscImpactoAmbiental                 0
# DscImpactoSocioEconomico            0
# DscPSBElaborado                     0
# DatConclusaoPSB                  2751
# DatPrevistaConclusaoPSB         11341
# DscPAEElaborado                     0
# DatConclusaoPAE                  3290
# DatPrevistaConclusaoPAE         11471
# DscISRRealizada                     0
# DatConclusaoISR                  2687
# DatPrevistaConclusaoISR         11350
# DscISERealizada                     0
# DatConclusaoISE                  8206
# DatPrevistaConclusaoISE         11342
# QtdMunicipioAfetado                 0
# MdaVazaoVertedouro               4591
# MdaCotaCoroamentoBarramento      4591
# NomTipoEstrutural                   0
# DscTipoEstrutural                   0
# DscEstudoRompimento              4609
# DscFinalidade                    6356
# DscEnquadraResolucao                0
# ...

# %% [markdown]
# Podemos ver que temos colunas com muito campos em branco, então as mesmas serão removidas

# %%
barragem.drop(['DatInicioConstrucao','MdaLatitude','MdaLongitude','DatPrevistaConclusaoPSB','DatPrevistaConclusaoPAE',
               'DatPrevistaConclusaoISR','DatPrevistaConclusaoISE'],
              axis=1,inplace=True)
barragem.head()
# Out:
#   DatGeracaoConjuntoDados  IdeNucleoCEG       NomUsina  \
# 0              2024-05-01          66.0  Alto Araguaia
# 1              2024-05-01          76.0    Alto Jatapu
# 2              2024-05-01          76.0    Alto Jatapu
# 3              2024-05-01          76.0    Alto Jatapu
# 4              2024-05-01          76.0    Alto Jatapu
#
#                NomEmpresa       NomBarramento   DscTipo  \
# 0  PRIMAVERA ENERGIA S.A.       Alto Araguaia  Barragem
# 1    Roraima Energia S.A.  BARRAGEM PRINCIPAL  Barragem
# 2    Roraima Energia S.A.          VERTEDOURO  Barragem
# 3    Roraima Energia S.A.               USINA  Barragem
# 4    Roraima Energia S.A.           DIQUE N°1     Dique
#
#   DscNivelSegurancaBarragem IdcClassificacaoBarragens DscCategoriaRiscoGeral  \
# 0                    Normal                         C                  BAIXO
# 1                    Normal                         C                  BAIXO
# ...

# %%
# filtrar para o rio grande do sul
barragem_rs = barragem[barragem['SigEstadoUsina']=='RS']
barragem_rs.head()
# Out:
#     DatGeracaoConjuntoDados  IdeNucleoCEG      NomUsina  \
# 53               2024-05-01          12.0  14 de Julho
# 101              2024-05-01         324.0        Bugres
# 102              2024-05-01         324.0        Bugres
# 103              2024-05-01         324.0        Bugres
# 104              2024-05-01         329.0        Buricá
#
#                                             NomEmpresa NomBarramento  \
# 53                  COMPANHIA ENERGÉTICA RIO DAS ANTAS   14 de Julho
# 101  Companhia Estadual de Geração de Energia Elétr...        Divisa
# 102  Companhia Estadual de Geração de Energia Elétr...         Blang
# 103  Companhia Estadual de Geração de Energia Elétr...         Salto
# 104  COOPERATIVA DE DESENVOLVIMENTO SOCIAL ENTRE RI...    PCH BURICÁ
#
#       DscTipo DscNivelSegurancaBarragem IdcClassificacaoBarragens  \
# 53   Barragem                    Normal                         B
# 101  Barragem                    Normal                         C
# ...

# %%
barragem_rs.reset_index(inplace=True)
barragem_rs.drop('index',axis=1,inplace=True)
barragem_rs.head()
# Out:
# <ipython-input-8-1b7fd6734b10>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   barragem_rs.drop('index',axis=1,inplace=True)
#   DatGeracaoConjuntoDados  IdeNucleoCEG      NomUsina  \
# 0              2024-05-01          12.0  14 de Julho
# 1              2024-05-01         324.0        Bugres
# 2              2024-05-01         324.0        Bugres
# 3              2024-05-01         324.0        Bugres
# 4              2024-05-01         329.0        Buricá
#
#                                           NomEmpresa NomBarramento   DscTipo  \
# 0                 COMPANHIA ENERGÉTICA RIO DAS ANTAS   14 de Julho  Barragem
# 1  Companhia Estadual de Geração de Energia Elétr...        Divisa  Barragem
# 2  Companhia Estadual de Geração de Energia Elétr...         Blang  Barragem
# ...

# %%
barragem_rs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   DatGeracaoConjuntoDados         1224 non-null   object
#  1   IdeNucleoCEG                    1224 non-null   float64
#  2   NomUsina                        1224 non-null   object
#  3   NomEmpresa                      1224 non-null   object
#  4   NomBarramento                   1224 non-null   object
#  5   DscTipo                         1224 non-null   object
#  6   DscNivelSegurancaBarragem       1224 non-null   object
#  7   IdcClassificacaoBarragens       1131 non-null   object
#  8   DscCategoriaRiscoGeral          1131 non-null   object
#  9   DscDanoPotencialGeral           1224 non-null   object
#  10  DscVersao                       1224 non-null   object
#  11  NomCampanha                     1224 non-null   object
# ...

# %%
barragem_rs.drop(['DatConclusaoISE','DscFinalidade'],axis=1,inplace=True)
barragem_rs.head()
# Out:
# <ipython-input-10-892fddf0cb4e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   barragem_rs.drop(['DatConclusaoISE','DscFinalidade'],axis=1,inplace=True)
#   DatGeracaoConjuntoDados  IdeNucleoCEG      NomUsina  \
# 0              2024-05-01          12.0  14 de Julho
# 1              2024-05-01         324.0        Bugres
# 2              2024-05-01         324.0        Bugres
# 3              2024-05-01         324.0        Bugres
# 4              2024-05-01         329.0        Buricá
#
#                                           NomEmpresa NomBarramento   DscTipo  \
# 0                 COMPANHIA ENERGÉTICA RIO DAS ANTAS   14 de Julho  Barragem
# 1  Companhia Estadual de Geração de Energia Elétr...        Divisa  Barragem
# ...

# %%
barragem_rs.tail()
# Out:
#      DatGeracaoConjuntoDados  IdeNucleoCEG                NomUsina  \
# 1219              2024-05-01       38225.0  Santo Antônio De Casca
# 1220              2024-05-01       38245.0                 Faxinal
# 1221              2024-05-01       45162.0   São Domingos do Prata
# 1222              2024-05-01       50288.0             Formigueiro
# 1223              2024-05-01       71326.0       Focchezan Energia
#
#                                              NomEmpresa  \
# 1219              SANTO ANTONIO GERACAO DE ENERGIA LTDA
# 1220                    FAXINAL GERAÇÃO DE ENERGIA LTDA
# 1221                   Usina São Domingos do Prata LTDA
# 1222  Formigueiro Geração E Comércio De Energia Elét...
# 1223                            Focchezan Energia LTDA.
#
#                     NomBarramento   DscTipo DscNivelSegurancaBarragem  \
# 1219       Santo Antônio de Casca  Barragem                    Normal
# 1220                      Faxinal  Barragem                    Normal
# ...

# %%
barragem_rs['DatGeracaoConjuntoDados'].unique()
# Out:
# array(['2024-05-01'], dtype=object)

# %% [markdown]
# Removeremos a coluna 'DatGeracaoConjuntoDados' pois está marca na data 01-05-2024 logo não será interessante ter essa coluna

# %%
barragem_rs.drop('DatGeracaoConjuntoDados',axis=1,inplace=True)
barragem_rs.head()
# Out:
# <ipython-input-13-f9a050963c61>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   barragem_rs.drop('DatGeracaoConjuntoDados',axis=1,inplace=True)
#    IdeNucleoCEG      NomUsina  \
# 0          12.0  14 de Julho
# 1         324.0        Bugres
# 2         324.0        Bugres
# 3         324.0        Bugres
# 4         329.0        Buricá
#
#                                           NomEmpresa NomBarramento   DscTipo  \
# 0                 COMPANHIA ENERGÉTICA RIO DAS ANTAS   14 de Julho  Barragem
# 1  Companhia Estadual de Geração de Energia Elétr...        Divisa  Barragem
# 2  Companhia Estadual de Geração de Energia Elétr...         Blang  Barragem
# 3  Companhia Estadual de Geração de Energia Elétr...         Salto  Barragem
# ...

# %%
barragem_rs.iloc[:,0:20].head()
# Out:
#    IdeNucleoCEG      NomUsina  \
# 0          12.0  14 de Julho
# 1         324.0        Bugres
# 2         324.0        Bugres
# 3         324.0        Bugres
# 4         329.0        Buricá
#
#                                           NomEmpresa NomBarramento   DscTipo  \
# 0                 COMPANHIA ENERGÉTICA RIO DAS ANTAS   14 de Julho  Barragem
# 1  Companhia Estadual de Geração de Energia Elétr...        Divisa  Barragem
# 2  Companhia Estadual de Geração de Energia Elétr...         Blang  Barragem
# 3  Companhia Estadual de Geração de Energia Elétr...         Salto  Barragem
# 4  COOPERATIVA DE DESENVOLVIMENTO SOCIAL ENTRE RI...    PCH BURICÁ  Barragem
#
#   DscNivelSegurancaBarragem IdcClassificacaoBarragens DscCategoriaRiscoGeral  \
# 0                    Normal                         B                  BAIXO
# 1                    Normal                         C                  BAIXO
# 2                    Normal                         B                  BAIXO
# ...

# %%
barragem['DatInicioPrazoLegalCampanha'].unique()
# Out:
# array(['2016-11-01', '2017-11-01', '2018-11-01', '2019-11-01',
#        '2020-04-21', '2020-11-01', '2021-11-01', '2022-11-01',
#        '2023-11-01'], dtype=object)

# %%
barragem_rs['NomEmpresa'] = barragem_rs['NomEmpresa'].str.capitalize()
barragem_rs['DscCategoriaRiscoGeral'] = barragem_rs['DscCategoriaRiscoGeral'].str.capitalize()
barragem_rs['DscDanoPotencialGeral'] = barragem_rs['DscDanoPotencialGeral'].str.capitalize()

barragem_rs['DatInicioCampanha'] = pd.to_datetime(barragem_rs['DatInicioCampanha'],
                                                  format='%Y-%m-%d')
barragem_rs['DatFimCampanha'] = pd.to_datetime(barragem_rs['DatFimCampanha'],
                                                  format='%Y-%m-%d')
barragem_rs['DatInicioPrazoLegalCampanha'] = pd.to_datetime(barragem_rs['DatInicioPrazoLegalCampanha'],
                                                  format='%Y-%m-%d')
barragem_rs['DatFimPrazoLegalCampanha'] = pd.to_datetime(barragem_rs['DatFimPrazoLegalCampanha'],
                                                  format='%Y-%m-%d')
barragem_rs['DatConclusaoConstrucao'] = pd.to_datetime(barragem_rs['DatConclusaoConstrucao'],
                                                  format='%Y-%m-%d')

barragem_rs['MdaAlturaMacicoFundacao'] = barragem_rs['MdaAlturaMacicoFundacao'].str.replace(',','.')
barragem_rs['MdaAlturaMacicoFundacao'] = barragem_rs['MdaAlturaMacicoFundacao'].astype(float)

barragem_rs['MdaComprimento'] = barragem_rs['MdaComprimento'].str.replace(',','.')
barragem_rs['MdaComprimento'] = barragem_rs['MdaComprimento'].astype(float)

barragem_rs.iloc[:,0:20].head()
# Out:
# <ipython-input-16-e3ac19fba5e7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   barragem_rs['NomEmpresa'] = barragem_rs['NomEmpresa'].str.capitalize()
# <ipython-input-16-e3ac19fba5e7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   barragem_rs['DscCategoriaRiscoGeral'] = barragem_rs['DscCategoriaRiscoGeral'].str.capitalize()
# <ipython-input-16-e3ac19fba5e7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
barragem_rs.iloc[:,20:40].head()
# Out:
#    NumBarramento DscExisteAcidenteIncidente  QtdAcidenteIncidente  \
# 0              1                        Não                     0
# 1              3                        Não                     0
# 2              3                        Não                     0
# 3              3                        Não                     0
# 4              1                        Não                     0
#
#            DthCadastro             DthEnvio             DscEnvioPrazoLegal  \
# 0  2019-01-11 07:32:57  2017-01-31 00:00:00  Enviado Dentro do Prazo Legal
# 1  2019-01-11 08:03:23  2017-01-31 00:00:00  Enviado Dentro do Prazo Legal
# 2  2019-01-11 08:03:23  2017-01-31 00:00:00  Enviado Dentro do Prazo Legal
# 3  2019-01-11 08:03:23  2017-01-31 00:00:00  Enviado Dentro do Prazo Legal
# 4  2019-01-11 08:27:12  2017-01-31 00:00:00  Enviado Dentro do Prazo Legal
#
#   NomRioEmpreendimento MdaCapacidadeTotalEmp DatPrimeiroEnchimento  \
# ...

# %%
barragem_rs['DthCadastro'] = barragem_rs['DthCadastro'].str.rsplit('.').str.get(0)
barragem_rs['DthCadastro'] = pd.to_datetime(barragem_rs['DthCadastro'])

barragem_rs['DthEnvio'] = barragem_rs['DthEnvio'].str.rsplit('.').str.get(0)
barragem_rs['DthEnvio'] = pd.to_datetime(barragem_rs['DthEnvio'])

barragem_rs['DatPrimeiroEnchimento'] = barragem_rs['DatPrimeiroEnchimento'].str.rsplit('.').str.get(0)
barragem_rs['DatPrimeiroEnchimento'] = pd.to_datetime(barragem_rs['DatPrimeiroEnchimento'])

barragem_rs['NomRioEmpreendimento'] = barragem_rs['NomRioEmpreendimento'].str.capitalize()

barragem_rs['MdaCapacidadeTotalEmp'] = barragem_rs['MdaCapacidadeTotalEmp'].str.replace(',','.')
barragem_rs['MdaCapacidadeTotalEmp'] = barragem_rs['MdaCapacidadeTotalEmp'].astype(float)

barragem_rs['MdaAreaSuperficieReservatorio'] = barragem_rs['MdaAreaSuperficieReservatorio'].str.replace(',00','0')
barragem_rs['MdaAreaSuperficieReservatorio'] = barragem_rs['MdaAreaSuperficieReservatorio'].str.replace(',','.')
barragem_rs['MdaAreaSuperficieReservatorio'] = barragem_rs['MdaAreaSuperficieReservatorio'].astype(float)

barragem_rs['MdaPotenciaImplantacao'] = barragem_rs['MdaPotenciaImplantacao'].str.replace(',','.')
barragem_rs['MdaPotenciaImplantacao'] = barragem_rs['MdaPotenciaImplantacao'].astype(float)

barragem_rs['PctParticipacaoEmpreendimento'] = barragem_rs['PctParticipacaoEmpreendimento'].str.replace(',','.')
barragem_rs['PctParticipacaoEmpreendimento'] = barragem_rs['PctParticipacaoEmpreendimento'].astype(float)

barragem_rs.iloc[:,20:40].head()
# Out:
# <ipython-input-18-fccc1995129f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   barragem_rs['DthCadastro'] = barragem_rs['DthCadastro'].str.rsplit('.').str.get(0)
# <ipython-input-18-fccc1995129f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   barragem_rs['DthCadastro'] = pd.to_datetime(barragem_rs['DthCadastro'])
# <ipython-input-18-fccc1995129f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
barragem_rs.iloc[:,40:60].head()
# Out:
#                                      DscTipoFundacao  \
# 0                                           Rocha Sã
# 1                 Rocha alterada dura com tratamento
# 2  Rocha alterada sem tratramento / Rocha alterad...
# 3  Rocha alterada sem tratramento / Rocha alterad...
# 4                                           Rocha Sã
#
#   DscTipoConstrucaoBarragem               DscEstimativaVazaoProjeto  \
# 0        Alvenaria de Pedra  (Cheia Máxima Provável) ou Decamilenar
# 1        Alvenaria de Pedra  (Cheia Máxima Provável) ou Decamilenar
# 2        Alvenaria de Pedra  (Cheia Máxima Provável) ou Decamilenar
# 3        Alvenaria de Pedra  (Cheia Máxima Provável) ou Decamilenar
# 4        Alvenaria de Pedra  (Cheia Máxima Provável) ou Decamilenar
#
#                                         DscCasaForca      DscComprimento  \
# 0  Casa de força associada à barragem por meio de...  Comprimento > 200m
# 1         Barragem/Dique sem Casa de Força associada  Comprimento > 200m
# ...

# %%
barragem['DscProbabilidadeMorte'].unique()
# Out:
# array(['INEXISTENTE (não existem pessoas permanentes/residentes ou temporárias/transitando na área afetada a  jusante da barragem)',
#        'POUCO FREQUENTE (não existem pessoas ocupando permanentemente a área afetada a  jusante da barragem, mas existe estrada vicinal de uso local)',
#        'EXISTENTE (existem pessoas ocupando permanentemente a área afetada a  jusante da barragem, portanto, vidas humanas poderão ser atingidas)',
#        'FREQUENTE  (não existem pessoas ocupando permanentemente a área afetada a jusante da barragem, mas existe rodovia municipal, estadual, federal ou outro local e/ou empreendimento de permanência eventual de pessoas que poderão ser atingidas)'],
#       dtype=object)

# %% [markdown]
# sobre probabilidade de morte (variavel)
#
# - inexistente: não existem pessoas permanentes/residentes ou temporárias/transitando na área afetada a  jusante da barragem
#
# - Pouco existente: não existem pessoas ocupando permanentemente a área afetada a  jusante da barragem, mas existe estrada vicinal de uso local
#
# - Existente: existem pessoas ocupando permanentemente a área afetada a  jusante da barragem, portanto, vidas humanas poderão ser atingidas
#
# - Frequente: não existem pessoas ocupando permanentemente a área afetada a jusante da barragem, mas existe rodovia municipal, estadual, federal ou outro local e/ou empreendimento de permanência eventual de pessoas que poderão ser atingidas

# %%
barragem_rs['DscProbabilidadeMorte'] = barragem['DscProbabilidadeMorte'].str.replace(r'\([^)]+\)', '')

barragem_rs['DscProbabilidadeMorte'] = barragem['DscProbabilidadeMorte'].str.capitalize()

barragem_rs.iloc[:,40:60].head()
# Out:
# <ipython-input-25-bf1fbd6e333e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   barragem_rs['DscProbabilidadeMorte'] = barragem['DscProbabilidadeMorte'].str.replace(r'\([^)]+\)', '')
# <ipython-input-25-bf1fbd6e333e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   barragem_rs['DscProbabilidadeMorte'] = barragem['DscProbabilidadeMorte'].str.capitalize()
#                                      DscTipoFundacao  \
# 0                                           Rocha Sã
# ...

# %%
barragem_rs.iloc[:,60:80].head()
# Out:
#                                  DscImpactoAmbiental  \
# 0  S - SIGNIFICATIVO (área afetada da barragem nã...
# 1  S - SIGNIFICATIVO (área afetada da barragem nã...
# 2  S - SIGNIFICATIVO (área afetada da barragem nã...
# 3  S - SIGNIFICATIVO (área afetada da barragem nã...
# 4  S - SIGNIFICATIVO (área afetada da barragem nã...
#
#                             DscImpactoSocioEconomico DscPSBElaborado  \
# 0  BAIXO ( existe pequena concentração de instala...             Não
# 1  BAIXO ( existe pequena concentração de instala...             Não
# 2  BAIXO ( existe pequena concentração de instala...             Não
# 3  BAIXO ( existe pequena concentração de instala...             Não
# 4  INEXISTENTE ( não existem quaisquer instalaçõe...             Não
#
#   DatConclusaoPSB DscPAEElaborado DatConclusaoPAE DscISRRealizada  \
# 0      1900-01-01   Não elaborado      1900-01-01             Não
# 1      1900-01-01   Não elaborado      1900-01-01             Não
# ...

# %%
barragem_rs.iloc[:,60:80].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   DscImpactoAmbiental          1224 non-null   object
#  1   DscImpactoSocioEconomico     1224 non-null   object
#  2   DscPSBElaborado              1224 non-null   object
#  3   DatConclusaoPSB              931 non-null    object
#  4   DscPAEElaborado              1224 non-null   object
#  5   DatConclusaoPAE              843 non-null    object
#  6   DscISRRealizada              1224 non-null   object
#  7   DatConclusaoISR              917 non-null    object
#  8   DscISERealizada              1224 non-null   object
#  9   QtdMunicipioAfetado          1224 non-null   int64
#  10  MdaVazaoVertedouro           764 non-null    object
#  11  MdaCotaCoroamentoBarramento  764 non-null    object
#  12  NomTipoEstrutural            1224 non-null   object
# ...

# %%
barragem['DscImpactoAmbiental'].unique()
# Out:
# array(['S - SIGNIFICATIVO (área afetada da barragem não representa área de interesse ambiental, áreas protegidas em legislação específica ou encontra-se totalmente descaracterizada de suas condições naturais)',
#        'MS - MUITO SIGNIFICATIVO (área afetada da barragem apresenta interesse ambiental relevante ou protegida em legislação específica)'],
#       dtype=object)

# %%
barragem['DscImpactoSocioEconomico'].unique()
# Out:
# array(['INEXISTENTE ( não existem quaisquer instalações e serviços de navegação na área afetada por acidente da barragem)',
#        'BAIXO ( existe pequena concentração de instalações residenciais e comerciais, agrícolas, industriais ou de infraestrutura  na área afetada da barragem ou instalações portuárias ou serviços de navegação)',
#        'ALTO (existe grande concentração de  instalações residenciais e comerciais, agrícolas, industriais, de infraestrutura e serviços de lazer e turismo na área afetada da barragem ou instalações portuárias ou serviços de navegação)'],
#       dtype=object)

# %%
barragem_rs['DscImpactoAmbiental'] = barragem['DscImpactoAmbiental'].str.replace(r'\([^)]+\)', '')
barragem_rs['DscImpactoAmbiental'] = barragem['DscImpactoAmbiental'].str.capitalize()

barragem_rs['DscImpactoSocioEconomico'] = barragem['DscImpactoSocioEconomico'].str.replace(r'\([^)]+\)', '')
barragem_rs['DscImpactoSocioEconomico'] = barragem['DscImpactoSocioEconomico'].str.capitalize()

barragem_rs['DatConclusaoPSB'] = pd.to_datetime(barragem_rs['DatConclusaoPSB'])
barragem_rs['DatConclusaoPAE'] = pd.to_datetime(barragem_rs['DatConclusaoPAE'])
barragem_rs['DatConclusaoISR'] = pd.to_datetime(barragem_rs['DatConclusaoISR'])

barragem_rs.iloc[:,60:80].head()
# Out:
# <ipython-input-30-17fa42085bc7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   barragem_rs['DscImpactoAmbiental'] = barragem['DscImpactoAmbiental'].str.replace(r'\([^)]+\)', '')
# <ipython-input-30-17fa42085bc7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   barragem_rs['DscImpactoAmbiental'] = barragem['DscImpactoAmbiental'].str.capitalize()
# <ipython-input-30-17fa42085bc7>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
barragem_rs.iloc[:,60:80].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   DscImpactoAmbiental          1224 non-null   object
#  1   DscImpactoSocioEconomico     1224 non-null   object
#  2   DscPSBElaborado              1224 non-null   object
#  3   DatConclusaoPSB              931 non-null    datetime64[ns]
#  4   DscPAEElaborado              1224 non-null   object
#  5   DatConclusaoPAE              843 non-null    datetime64[ns]
#  6   DscISRRealizada              1224 non-null   object
#  7   DatConclusaoISR              917 non-null    datetime64[ns]
#  8   DscISERealizada              1224 non-null   object
#  9   QtdMunicipioAfetado          1224 non-null   int64
#  10  MdaVazaoVertedouro           764 non-null    object
#  11  MdaCotaCoroamentoBarramento  764 non-null    object
# ...

# %%
barragem_rs.to_csv('Fisc barra rs.csv')
